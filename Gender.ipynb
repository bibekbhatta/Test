# %%
# !pip install gender_guesser
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 379.3/379.3 kB 7.2 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import pandas as pd

# %%
df=pd.DataFrame({'Names': ['James',
                            'tom',
                            'Mary', 
                            'lucy',
                           'bibek',
                            'david',
                           'katie'
                            ]})

# %%
df
# Out:
#    Names
# 0  James
# 1    tom
# 2   Mary
# 3   lucy
# 4  bibek
# 5  david
# 6  katie

# %%
import gender_guesser.detector as gender

# %%
d = gender.Detector(case_sensitive=False)

# %%
df['Gen'] = df['Names'].apply(str.capitalize).map(lambda x: d.get_gender(x))

# %%
#df
